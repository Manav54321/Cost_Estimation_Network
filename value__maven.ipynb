# %% [markdown]
# <a href="https://colab.research.google.com/github/Manav54321/value_maven/blob/main/value__maven.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/laptop_data.csv')

# %%
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0       Inches          Price
# count  1303.00000  1303.000000    1303.000000
# mean    651.00000    15.017191   59870.042910
# std     376.28801     1.426304   37243.201786
# min       0.00000    10.100000    9270.720000
# 25%     325.50000    14.000000   31914.720000
# 50%     651.00000    15.600000   52054.560000
# 75%     976.50000    15.600000   79274.246400
# max    1302.00000    18.400000  324954.720000

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
# drop the unnamed feature
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.sample(10)
# Out:
#       Company            TypeName  Inches  \
# 1164       HP            Notebook    15.6
# 1114   Lenovo  2 in 1 Convertible    10.1
# 329      Dell            Notebook    15.6
# 304      Asus              Gaming    15.6
# 1245     Asus              Gaming    15.6
# 756        HP            Notebook    15.6
# 217        HP            Notebook    14.0
# 1015  Toshiba            Notebook    13.3
# 883    Lenovo            Notebook    15.6
# 636      Dell           Ultrabook    13.3
#
#                          ScreenResolution                          Cpu   Ram  \
# 1164                             1366x768   Intel Core i5 6200U 2.3GHz   4GB
# 1114      IPS Panel Touchscreen 1920x1200  Intel Atom x5-Z8550 1.44GHz   4GB
# 329   4K Ultra HD / Touchscreen 3840x2160  Intel Core i7 7700HQ 2.8GHz  32GB
# 304                     Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz   8GB
# 1245          IPS Panel Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz  16GB
# ...

# %%
df.duplicated().sum()
# Out:
# 29

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# in the Ram feature, replace GB with nothing and in weights feature, replace kg with nothing
df['Ram'] = df['Ram'].str.replace('GB', '')
df['Weight'] = df['Weight'].str.replace('kg', '')

# %%
df[['Ram', 'Weight']]
# Out:
#      Ram Weight
# 0      8   1.37
# 1      8   1.34
# 2      8   1.86
# 3     16   1.83
# 4      8   1.37
# ...   ..    ...
# 1269   4    2.2
# 1270   4    1.8
# 1271  16    1.3
# 1272   2    1.5
# 1273   6   2.19
#
# [1274 rows x 2 columns]

# %%
# now change the dtype of the ram and weights
df['Ram'] = df['Ram'].astype('int32')
df['Weight'] = df['Weight'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1274 entries, 0 to 1273
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1274 non-null   object
#  1   TypeName          1274 non-null   object
#  2   Inches            1274 non-null   float64
#  3   ScreenResolution  1274 non-null   object
#  4   Cpu               1274 non-null   object
#  5   Ram               1274 non-null   int32
#  6   Memory            1274 non-null   object
#  7   Gpu               1274 non-null   object
#  8   OpSys             1274 non-null   object
#  9   Weight            1274 non-null   float32
#  10  Price             1274 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 109.5+ KB

# %%
# EDA
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.kdeplot(df['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
sns.barplot(x=df['Company'], y=df['Price'], palette='hls')
plt.xticks(rotation='vertical')
plt.show()
# Out:
# <ipython-input-20-c8a4731fca44>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['Company'], y=df['Price'], palette='hls')

# %%
df['TypeName'].value_counts().plot(kind='bar', color='red')
# Out:
# <Axes: xlabel='TypeName'>

# %%
sns.barplot(x=df['TypeName'], y=df['Price'], palette='hls')
plt.xticks(rotation='vertical')
plt.show()
# Out:
# <ipython-input-22-4d15614177bd>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['TypeName'], y=df['Price'], palette='hls')

# %%
sns.histplot(df['Inches'], alpha=0.2, color='orange', linewidth=0.2, kde=True)
# Out:
# <Axes: xlabel='Inches', ylabel='Count'>

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                505
# 1366x768                                         262
# IPS Panel Full HD 1920x1080                      226
# IPS Panel Full HD / Touchscreen 1920x1080         51
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# ...

# %%
df['Touchscreen'] = df['ScreenResolution'].apply(lambda x: 1 if 'Touchscreen' in x else 0)

# %%
df['Touchscreen'].value_counts()
# Out:
# Touchscreen
# 0    1086
# 1     188
# Name: count, dtype: int64

# %%
df.sample(5)
# Out:
#        Company   TypeName  Inches             ScreenResolution  \
# 400     Lenovo   Notebook    15.6                     1366x768
# 127       Asus   Notebook    14.0                     1366x768
# 294     Lenovo   Notebook    15.6            Full HD 1920x1080
# 457  Microsoft  Ultrabook    13.5        Touchscreen 2256x1504
# 945     Lenovo     Gaming    15.6  IPS Panel Full HD 1920x1080
#
#                                       Cpu  Ram                Memory  \
# 400  Intel Celeron Dual Core N3350 1.1GHz    4               1TB HDD
# 127              AMD E-Series 6110 1.5GHz    4              64GB SSD
# 294            Intel Core i5 8250U 1.6GHz    8             256GB SSD
# 457           Intel Core M m3-7Y30 2.2GHz    4             128GB SSD
# 945                   AMD FX 8800P 2.1GHz   16  512GB SSD +  1TB HDD
#
#                         Gpu         OpSys  Weight       Price  Touchscreen
# 400   Intel HD Graphics 500    Windows 10   2.200  16303.6800            0
# ...

# %%
df['Touchscreen'].value_counts().plot(kind='bar', color='lime')
# Out:
# <Axes: xlabel='Touchscreen'>

# %%
# touchscreen and price plot
sns.barplot(x=df['Touchscreen'], y=df['Price'], palette='winter')
# Out:
# <ipython-input-120-ffe01d16c35f>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['Touchscreen'], y=df['Price'], palette='winter')
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %%
df['Ips'] = df['ScreenResolution'].apply(lambda x: 1 if 'IPS' in x else 0)

# %%
df['Ips'].value_counts()
# Out:
# Ips
# 0    917
# 1    357
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# ...

# %%
df['Ips'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Ips'>

# %%
sns.barplot(x=df['Ips'], y=df['Price'], palette='winter')
# Out:
# <ipython-input-34-8ee7e4aed718>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['Ips'], y=df['Price'], palette='winter')
# <Axes: xlabel='Ips', ylabel='Price'>

# %%
df['ScreenResolution'].str.split()
# Out:
# 0                [IPS, Panel, Retina, Display, 2560x1600]
# 1                                              [1440x900]
# 2                                   [Full, HD, 1920x1080]
# 3                [IPS, Panel, Retina, Display, 2880x1800]
# 4                [IPS, Panel, Retina, Display, 2560x1600]
#                               ...
# 1269                                           [1366x768]
# 1270    [IPS, Panel, Full, HD, /, Touchscreen, 1920x1080]
# 1271    [IPS, Panel, Quad, HD+, /, Touchscreen, 3200x1...
# 1272                                           [1366x768]
# 1273                                           [1366x768]
# Name: ScreenResolution, Length: 1274, dtype: object

# %%
# split the resolutions
df['res'] = df['ScreenResolution'].str.split().str[-1]

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1269    Asus            Notebook    15.6
# 1270  Lenovo  2 in 1 Convertible    14.0
# 1271  Lenovo  2 in 1 Convertible    13.3
# 1272  Lenovo            Notebook    14.0
# 1273      HP            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1269                                    1366x768
# 1270   IPS Panel Full HD / Touchscreen 1920x1080
# ...

# %%
df['x_res'] = df['res'].str.split('x').str[0]
df['x_res']
# Out:
# 0       2560
# 1       1440
# 2       1920
# 3       2880
# 4       2560
#         ...
# 1269    1366
# 1270    1920
# 1271    3200
# 1272    1366
# 1273    1366
# Name: x_res, Length: 1274, dtype: object

# %%
df['y_res'] = df['res'].str.split('x').str[1]
df['y_res']
# Out:
# 0       1600
# 1        900
# 2       1080
# 3       1800
# 4       1600
#         ...
# 1269     768
# 1270    1080
# 1271    1800
# 1272     768
# 1273     768
# Name: y_res, Length: 1274, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1274 entries, 0 to 1273
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1274 non-null   object
#  1   TypeName          1274 non-null   object
#  2   Inches            1274 non-null   float64
#  3   ScreenResolution  1274 non-null   object
#  4   Cpu               1274 non-null   object
#  5   Ram               1274 non-null   int32
#  6   Memory            1274 non-null   object
#  7   Gpu               1274 non-null   object
#  8   OpSys             1274 non-null   object
#  9   Weight            1274 non-null   float32
#  10  Price             1274 non-null   float64
#  11  Touchscreen       1274 non-null   int64
#  12  Ips               1274 non-null   int64
#  13  res               1274 non-null   object
#  14  x_res             1274 non-null   object
#  15  y_res             1274 non-null   object
# ...

# %%
# convert x_res and y_res to int
df['x_res'] = df['x_res'].astype('int32')
df['y_res'] = df['y_res'].astype('int32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1274 entries, 0 to 1273
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1274 non-null   object
#  1   TypeName          1274 non-null   object
#  2   Inches            1274 non-null   float64
#  3   ScreenResolution  1274 non-null   object
#  4   Cpu               1274 non-null   object
#  5   Ram               1274 non-null   int32
#  6   Memory            1274 non-null   object
#  7   Gpu               1274 non-null   object
#  8   OpSys             1274 non-null   object
#  9   Weight            1274 non-null   float32
#  10  Price             1274 non-null   float64
#  11  Touchscreen       1274 non-null   int64
#  12  Ips               1274 non-null   int64
#  13  res               1274 non-null   object
#  14  x_res             1274 non-null   int32
#  15  y_res             1274 non-null   int32
# ...

# %%
# drop res feature
df.drop('res', axis=1, inplace=True)

# %%
df.select_dtypes(include=['number']).corr()['Price']
# Out:
# Inches         0.066990
# Ram            0.740106
# Weight         0.212192
# Price          1.000000
# Touchscreen    0.188631
# Ips            0.250358
# x_res          0.552074
# y_res          0.548111
# Name: Price, dtype: float64

# %%
df['ppi'] = ((df['x_res']**2) + (df['y_res']**2))**0.5 / df['Inches']
# Pixels per inch
df['ppi'].astype('float32')
# Out:
# 0       226.983002
# 1       127.677940
# 2       141.212006
# 3       220.534622
# 4       226.983002
#            ...
# 1269    100.454666
# 1270    157.350510
# 1271    276.053528
# 1272    111.935204
# 1273    100.454666
# Name: ppi, Length: 1274, dtype: float32

# %%
df.select_dtypes(include=['number']).corr()['Price']
# Out:
# Inches         0.066990
# Ram            0.740106
# Weight         0.212192
# Price          1.000000
# Touchscreen    0.188631
# Ips            0.250358
# x_res          0.552074
# y_res          0.548111
# ppi            0.469539
# Name: Price, dtype: float64

# %%
df.drop(columns=['ScreenResolution'], axis=1, inplace=True)

# %%
df.drop(columns=['Inches', 'x_res', 'y_res'], axis=1, inplace=True)

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz     190
# Intel Core i7 7700HQ 2.8GHz    146
# Intel Core i7 7500U 2.7GHz     132
# Intel Core i7 8550U 1.8GHz      73
# Intel Core i5 8250U 1.6GHz      72
#                               ...
# Intel Core M M3-6Y30 0.9GHz      1
# AMD A9-Series 9420 2.9GHz        1
# Intel Core i5 2.9GHz             1
# AMD A6-Series 7310 2GHz          1
# AMD A9-Series 9410 2.9GHz        1
# Name: count, Length: 118, dtype: int64

# %%
df['Cpu_name'] = df['Cpu'].str.split().str[0:3]
# first three words

# %%
df['Cpu_name'] = df['Cpu_name'].str.join(" ")

# %%
def fetch_processor(text):
  if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
    return text
  else:
    if text.split()[0] == 'Intel':
      return 'Other Intel Processor'
    else:
      return 'AMD Processor'

# %%
df['Cpu_brand'] = df['Cpu_name'].apply(fetch_processor)

# %%
df['Cpu_brand'].value_counts()
# Out:
# Cpu_brand
# Intel Core i7            515
# Intel Core i5            423
# Other Intel Processor    141
# Intel Core i3            134
# AMD Processor             61
# Name: count, dtype: int64

# %%
df['Cpu_brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cpu_brand'>

# %%
# price and processor curve
sns.barplot(x=df['Cpu_brand'], y=df['Price'], palette='winter')
plt.xticks(rotation='vertical')
plt.show()
# Out:
# <ipython-input-56-646dc0c606a5>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['Cpu_brand'], y=df['Price'], palette='winter')

# %%
df
# Out:
#      Company            TypeName                                   Cpu  Ram  \
# 0      Apple           Ultrabook                  Intel Core i5 2.3GHz    8
# 1      Apple           Ultrabook                  Intel Core i5 1.8GHz    8
# 2         HP            Notebook            Intel Core i5 7200U 2.5GHz    8
# 3      Apple           Ultrabook                  Intel Core i7 2.7GHz   16
# 4      Apple           Ultrabook                  Intel Core i5 3.1GHz    8
# ...      ...                 ...                                   ...  ...
# 1269    Asus            Notebook            Intel Core i7 6500U 2.5GHz    4
# 1270  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz    4
# 1271  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz   16
# 1272  Lenovo            Notebook  Intel Celeron Dual Core N3050 1.6GHz    2
# 1273      HP            Notebook            Intel Core i7 6500U 2.5GHz    6
#
# ...

# %%
df.drop(columns=['Cpu', 'Cpu_name'], axis=1, inplace=True)

# %%
df
# Out:
#      Company            TypeName  Ram               Memory  \
# 0      Apple           Ultrabook    8            128GB SSD
# 1      Apple           Ultrabook    8  128GB Flash Storage
# 2         HP            Notebook    8            256GB SSD
# 3      Apple           Ultrabook   16            512GB SSD
# 4      Apple           Ultrabook    8            256GB SSD
# ...      ...                 ...  ...                  ...
# 1269    Asus            Notebook    4            500GB HDD
# 1270  Lenovo  2 in 1 Convertible    4            128GB SSD
# 1271  Lenovo  2 in 1 Convertible   16            512GB SSD
# 1272  Lenovo            Notebook    2   64GB Flash Storage
# 1273      HP            Notebook    6              1TB HDD
#
#                                Gpu       OpSys  Weight        Price  \
# 0     Intel Iris Plus Graphics 640       macOS    1.37   71378.6832
# 1           Intel HD Graphics 6000       macOS    1.34   47895.5232
# ...

# %%
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Ram'>

# %%
# ram and price curve:
sns.barplot(x=df['Ram'], y=df['Price'], palette='summer')
plt.xticks(rotation='vertical')
plt.show()
# Out:
# <ipython-input-61-ef5f950647fc>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['Ram'], y=df['Price'], palette='summer')

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          215
# 500GB HDD                        123
# 512GB SSD                        114
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         74
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                36
# 2TB HDD                           16
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 64GB Flash Storage                13
# 256GB SSD +  2TB HDD              10
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 1.0TB Hybrid                       7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')
new = df["Memory"].str.split("+", n = 1, expand = True)

df["first"]= new[0]
df["first"]=df["first"].str.strip()

df["second"]= new[1]

df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['first'] = df['first'].str.replace(r'\D', '', regex=True).astype('int64')

df["second"].fillna("0", inplace = True)

df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['second'] = df['second'].str.replace(r'\D', '', regex=True).astype('int64')
#The regex=True argument is added to ensure that the pattern is treated as a regular expression.

df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
df["SSD"]=(df["first"]*df["Layer1SSD"]+df["second"]*df["Layer2SSD"])
df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])
df["Flash_Storage"]=(df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])

df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)

# %%
df.sample(20)
# Out:
#      Company            TypeName  Ram               Memory  \
# 319     Acer            Notebook    4    128 Flash Storage
# 316       HP  2 in 1 Convertible   16             1000 SSD
# 677       HP  2 in 1 Convertible    8     64 Flash Storage
# 858     Dell            Notebook    8             1000 HDD
# 880       HP  2 in 1 Convertible    4              256 SSD
# 803     Dell            Notebook    8              256 SSD
# 798   Lenovo  2 in 1 Convertible    8              256 SSD
# 697     Asus  2 in 1 Convertible    4     64 Flash Storage
# 1204    Asus              Gaming    8             1000 HDD
# 1178     MSI              Gaming   16  128 SSD +  1000 HDD
# 1202    Dell  2 in 1 Convertible   16              512 SSD
# 1255    Asus            Notebook    4             1000 HDD
# 103       HP           Ultrabook    8              256 SSD
# 553       HP            Notebook    8             1000 HDD
# 824   Lenovo           Ultrabook    8    256 Flash Storage
# ...

# %%
df.drop(columns=['Memory'], axis=1, inplace=True)

# %%
# correlation of (HDD, SSD, Hybrid, and Flash_Storage) with price
df.select_dtypes(include=['number']).corr()['Price']
# Out:
# Ram              0.740106
# Weight           0.212192
# Price            1.000000
# Touchscreen      0.188631
# Ips              0.250358
# ppi              0.469539
# HDD             -0.098011
# SSD              0.669957
# Hybrid           0.022533
# Flash_Storage   -0.037176
# Name: Price, dtype: float64

# %%
df.drop(columns=['Hybrid', 'Flash_Storage'], axis=1, inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips         ppi      Cpu_brand  HDD  SSD
# 0   71378.6832            0    1  226.983005  Intel Core i5    0  128
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0    0  141.211998  Intel Core i5    0  256
# 3  135195.3360            0    1  220.534624  Intel Core i7    0  512
# 4   96095.8080            0    1  226.983005  Intel Core i5    0  256

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      279
# Intel HD Graphics 520      181
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
df['gpu_brand'] = df['Gpu'].str.split().str[0]

# %%
df['gpu_brand'].value_counts()
# Out:
# gpu_brand
# Intel     703
# Nvidia    396
# AMD       174
# ARM         1
# Name: count, dtype: int64

# %%
df = df[df['gpu_brand'] != 'ARM']

# %%
sns.barplot(x=df['gpu_brand'], y=df['Price'], palette='winter', estimator = np.median)
plt.xticks(rotation='vertical')
plt.show()
# Out:
# <ipython-input-73-05064ccab637>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['gpu_brand'], y=df['Price'], palette='winter', estimator = np.median)

# %%
df.drop(columns=['Gpu'], axis=1, inplace=True)
# Out:
# <ipython-input-74-47acafc873ae>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Gpu'], axis=1, inplace=True)

# %%
df
# Out:
#      Company            TypeName  Ram       OpSys  Weight        Price  \
# 0      Apple           Ultrabook    8       macOS    1.37   71378.6832
# 1      Apple           Ultrabook    8       macOS    1.34   47895.5232
# 2         HP            Notebook    8       No OS    1.86   30636.0000
# 3      Apple           Ultrabook   16       macOS    1.83  135195.3360
# 4      Apple           Ultrabook    8       macOS    1.37   96095.8080
# ...      ...                 ...  ...         ...     ...          ...
# 1269    Asus            Notebook    4  Windows 10    2.20   38378.6496
# 1270  Lenovo  2 in 1 Convertible    4  Windows 10    1.80   33992.6400
# 1271  Lenovo  2 in 1 Convertible   16  Windows 10    1.30   79866.7200
# 1272  Lenovo            Notebook    2  Windows 10    1.50   12201.1200
# 1273      HP            Notebook    6  Windows 10    2.19   40705.9200
#
#       Touchscreen  Ips         ppi              Cpu_brand   HDD  SSD gpu_brand
# ...

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1047
# No OS             66
# Linux             58
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
# make operating systems category as mac windows linux and others
def cat_os(text):
  if text == 'Windows 10' or text == 'Windows 7' or text == 'Windows' or text == 'Windows 10 S':
    return 'Windows'
  elif text == 'Mac' or text == 'Mac OS X':
    return 'Mac'
  else:
    return 'Linux_and_others'

# %%
df['os'] = df['OpSys'].apply(cat_os)
# Out:
# <ipython-input-78-38671a3c07bd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['os'] = df['OpSys'].apply(cat_os)

# %%
df['os'].value_counts()
# Out:
# os
# Windows             1100
# Linux_and_others     165
# Mac                    8
# Name: count, dtype: int64

# %%
df.drop(columns=['OpSys'], axis=1, inplace=True)
# Out:
# <ipython-input-80-f960c7396a12>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['OpSys'], axis=1, inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  Touchscreen  Ips         ppi  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34   47895.5232            0    0  127.677940
# 2      HP   Notebook    8    1.86   30636.0000            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83  135195.3360            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37   96095.8080            0    1  226.983005
#
#        Cpu_brand  HDD  SSD gpu_brand                os
# 0  Intel Core i5    0  128     Intel  Linux_and_others
# 1  Intel Core i5    0    0     Intel  Linux_and_others
# 2  Intel Core i5    0  256     Intel  Linux_and_others
# 3  Intel Core i7    0  512       AMD  Linux_and_others
# 4  Intel Core i5    0  256     Intel  Linux_and_others

# %%
# os and price curve
sns.barplot(x=df['os'], y=df['Price'], palette='rocket')
plt.xticks(rotation='vertical')
plt.show()
# Out:
# <ipython-input-82-7c313dba0379>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['os'], y=df['Price'], palette='rocket')

# %%
sns.histplot(df['Weight'], kde=True, color='orange', linewidth=0.1, alpha=0.1)
# Out:
# <Axes: xlabel='Weight', ylabel='Count'>

# %%
# scatterplot of weights and price
sns.scatterplot(x=df['Weight'], y=df['Price'], hue=df['os'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
# corr of price
df.select_dtypes(include=['number']).corr()['Price']
# Out:
# Ram            0.739996
# Weight         0.211667
# Price          1.000000
# Touchscreen    0.190382
# Ips            0.251514
# ppi            0.471481
# HDD           -0.098481
# SSD            0.669808
# Name: Price, dtype: float64

# %%
# corr matrix
sns.heatmap(df.select_dtypes(include=['number']).corr(), annot=True, cmap='winter')
# Out:
# <Axes: >

# %%
sns.histplot(df['Price'], kde=True, color='orange', linewidth=0.1, alpha=0.1)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
# the target feature price is skewed, so apply log transformation
df['Price'] = np.log(df['Price'])
# Out:
# <ipython-input-88-9dcb78cd42f4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Price'] = np.log(df['Price'])

# %%
sns.histplot(df['Price'], kde=True, color='orange', linewidth=0.1, alpha=0.1)
# after log transformation
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
X = df.drop(columns=['Price'], axis=1)
y = df['Price']

# %%
X
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  Ips         ppi  \
# 0      Apple           Ultrabook    8    1.37            0    1  226.983005
# 1      Apple           Ultrabook    8    1.34            0    0  127.677940
# 2         HP            Notebook    8    1.86            0    0  141.211998
# 3      Apple           Ultrabook   16    1.83            0    1  220.534624
# 4      Apple           Ultrabook    8    1.37            0    1  226.983005
# ...      ...                 ...  ...     ...          ...  ...         ...
# 1269    Asus            Notebook    4    2.20            0    0  100.454670
# 1270  Lenovo  2 in 1 Convertible    4    1.80            1    1  157.350512
# 1271  Lenovo  2 in 1 Convertible   16    1.30            1    1  276.053530
# 1272  Lenovo            Notebook    2    1.50            0    0  111.935204
# 1273      HP            Notebook    6    2.19            0    0  100.454670
#
# ...

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1269    10.555257
# 1270    10.433899
# 1271    11.288115
# 1272     9.409283
# 1273    10.614129
# Name: Price, Length: 1273, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=2)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score, mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor, ExtraTreesRegressor
from sklearn.svm import SVR

# %% [markdown]
# ## Linear regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse=False, drop='first'), ['Company', 'TypeName', 'Cpu_brand', 'gpu_brand', 'os'])
], remainder='passthrough')

step2 = LinearRegression()

pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

pipe.fit(X_train, y_train)

y_pred = pipe.predict(X_test)

print('R2 score', r2_score(y_test, y_pred))
print('MAE', mean_absolute_error(y_test, y_pred))
# Out:
# R2 score 0.7929909270090962
# MAE 0.22046852935748223
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# # Ridge Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = Ridge(alpha=10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.7920503733232036
# MAE 0.22555972913374675

# %% [markdown]
# ## Lasso Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = Lasso(alpha=0.001)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7911412768287943
# MAE 0.22445290863123896
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# ## KNN

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = KNeighborsRegressor(n_neighbors=3)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.7499866615593814
# MAE 0.213209323447066

# %% [markdown]
# ## Decision Tree

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = DecisionTreeRegressor(max_depth=8)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7996235995504178
# MAE 0.21974323672475696
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# ## SVM

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = SVR(kernel='rbf',C=10000,epsilon=0.1)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.820566750876081
# MAE 0.2092394835741459

# %% [markdown]
# ## Random Forest

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8466286461742769
# MAE 0.18538783480128565

# %% [markdown]
# ## ExtraTrees

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = ExtraTreesRegressor(n_estimators=100,
                              random_state=3,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8245840191794153
# MAE 0.18930148389155413

# %% [markdown]
# ## AdaBoost

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = AdaBoostRegressor(n_estimators=15,learning_rate=1.0)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7698709869629337
# MAE 0.24802225217263896
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# ## Gradient Boost

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = GradientBoostingRegressor(n_estimators=500)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8596567965802318
# MAE 0.18028444757563156

# %% [markdown]
# ## Voting (Regressor)

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor
# xgboost regressor
from xgboost import XGBRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')


rf = RandomForestRegressor(n_estimators=350,random_state=3,max_features=0.75,max_depth=15)
gbdt = GradientBoostingRegressor(n_estimators=100,max_features=0.5)
xgb = XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5)
et = ExtraTreesRegressor(n_estimators=100,random_state=3,max_features=0.75,max_depth=10)

estimators = [('rf', rf), ('gbdt', gbdt), ('xgb',xgb), ('et',et)]

step2 = VotingRegressor(estimators=estimators, weights=[1,2,100,1], n_jobs=10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.879091498499247
# MAE 0.16643502011588268

# %% [markdown]
# ## Stacking (Regressor)

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')


estimators = [
    ('rf', RandomForestRegressor(n_estimators=350,random_state=3,max_features=0.75,max_depth=15)),
    ('gbdt',GradientBoostingRegressor(n_estimators=100,max_features=0.5)),
    ('xgb', XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5))
]

step2 = StackingRegressor(estimators=estimators, final_estimator=Ridge(alpha=100))

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8415665479573694
# MAE 0.19534619016551374

# %% [markdown]
# ## Exporting the model

# %%
import pickle

pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
X_train.head()
# Out:
#       Company            TypeName  Ram  Weight  Touchscreen  Ips         ppi  \
# 1141      MSI              Gaming    8     2.4            0    0  141.211998
# 1052     Dell  2 in 1 Convertible    8     2.3            1    1  141.211998
# 971      Dell           Ultrabook    8     1.5            1    0  209.800683
# 405      Asus           Ultrabook    8     1.1            0    0  157.350512
# 1021  Toshiba           Ultrabook    8     1.2            0    0  165.632118
#
#           Cpu_brand   HDD  SSD gpu_brand       os
# 1141  Intel Core i7  1000  128    Nvidia  Windows
# 1052  Intel Core i5     0  256     Intel  Windows
# 971   Intel Core i7     0  256     Intel  Windows
# 405   Intel Core i7     0  512     Intel  Windows
# 1021  Intel Core i5     0  256     Intel  Windows

# %%
# predicion

new_laptop_data = pd.DataFrame({
    'Company': ['Apple'],
    'TypeName': ['Gaming'],
    'Ram': [16],
    'Weight': [1.3],
    'Touchscreen': [0],
    'Ips': [0],
    'ppi': [141.211998],
    'Cpu_brand': ['Intel Core i7'],
    'HDD': [1000],
    'SSD': [128],
    'gpu_brand': ['Nvidia'],
    'os': ['Mac']
})

predicted_price_log = pipe.predict(new_laptop_data)
predicted_price = np.exp(predicted_price_log)
print(predicted_price, "Rs")
# Out:
# [86706.00211314] Rs
